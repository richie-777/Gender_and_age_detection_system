# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.keras.layers import Dropout, Input, Add, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model

# %%
path = Path("OneDrive/Desktop/CODECLAUSE/Gender_and_age_detection/UTKFace")
filenames = list(map(lambda x: x.name, path.glob('*.jpg')))

# %%
print(len(filenames))
print(filenames[:3])
# Out:
# 23708
# ['100_0_0_20170112213500903.jpg.chip.jpg', '100_0_0_20170112215240346.jpg.chip.jpg', '100_1_0_20170110183726390.jpg.chip.jpg']

# %%
np.random.seed(10)
np.random.shuffle(filenames)

age_labels, gender_labels, image_path = [], [], []

for filename in filenames:
    image_path.append(filename)
    temp = filename.split('_')
    age_labels.append(temp[0])
    gender_labels.append(temp[1])

# %%
image_path[0:20]
# Out:
# ['23_1_2_20170116172910708.jpg.chip.jpg',
#  '28_0_1_20170113150719161.jpg.chip.jpg',
#  '26_1_0_20170116234741431.jpg.chip.jpg',
#  '37_0_3_20170119202516470.jpg.chip.jpg',
#  '60_0_0_20170109013457906.jpg.chip.jpg',
#  '2_0_2_20161219162359990.jpg.chip.jpg',
#  '8_0_0_20170110222913531.jpg.chip.jpg',
#  '34_1_4_20170113011428472.jpg.chip.jpg',
#  '48_1_0_20170109220544479.jpg.chip.jpg',
#  '54_0_0_20170113210319475.jpg.chip.jpg',
#  '63_0_0_20170113210318902.jpg.chip.jpg',
#  '35_1_1_20170113001239705.jpg.chip.jpg',
#  '9_1_0_20170109202813775.jpg.chip.jpg',
#  '29_1_1_20170116171830504.jpg.chip.jpg',
#  '56_1_0_20170103180406295.jpg.chip.jpg',
#  '35_0_3_20170119201257884.jpg.chip.jpg',
#  '5_0_0_20170109193414770.jpg.chip.jpg',
#  '1_0_2_20161219203256078.jpg.chip.jpg',
#  '14_0_3_20170104225721488.jpg.chip.jpg',
#  '27_0_0_20170113210319553.jpg.chip.jpg']

# %%
df = pd.DataFrame()
df['image'], df['age'], df['gender'] = image_path, age_labels, gender_labels

# %%
df.head(20)
# Out:
#                                     image   age  gender
# 0   23_1_2_20170116172910708.jpg.chip.jpg  23.0       1
# 1   28_0_1_20170113150719161.jpg.chip.jpg  28.0       0
# 2   26_1_0_20170116234741431.jpg.chip.jpg  26.0       1
# 3   37_0_3_20170119202516470.jpg.chip.jpg  37.0       0
# 4   60_0_0_20170109013457906.jpg.chip.jpg  60.0       0
# 5    2_0_2_20161219162359990.jpg.chip.jpg   2.0       0
# 6    8_0_0_20170110222913531.jpg.chip.jpg   8.0       0
# 7   34_1_4_20170113011428472.jpg.chip.jpg  34.0       1
# 8   48_1_0_20170109220544479.jpg.chip.jpg  48.0       1
# 9   54_0_0_20170113210319475.jpg.chip.jpg  54.0       0
# 10  63_0_0_20170113210318902.jpg.chip.jpg  63.0       0
# 11  35_1_1_20170113001239705.jpg.chip.jpg  35.0       1
# 12   9_1_0_20170109202813775.jpg.chip.jpg   9.0       1
# 13  29_1_1_20170116171830504.jpg.chip.jpg  29.0       1
# 14  56_1_0_20170103180406295.jpg.chip.jpg  56.0       1
# 15  35_0_3_20170119201257884.jpg.chip.jpg  35.0       0
# 16   5_0_0_20170109193414770.jpg.chip.jpg   5.0       0
# 17   1_0_2_20161219203256078.jpg.chip.jpg   1.0       0
# 18  14_0_3_20170104225721488.jpg.chip.jpg  14.0       0
# 19  27_0_0_20170113210319553.jpg.chip.jpg  27.0       0

# %%
gender_dict = {0:"Male",1:"Female"}

# %%
df = df.astype({'age':'float32', 'gender': 'int32'})

# %%
print(df.dtypes)
# Out:
# image      object
# age       float32
# gender      int32
# dtype: object

# %%
img = Image.open("OneDrive/Desktop/CODECLAUSE/Gender_and_age_detection/UTKFace/"+df.image[200])
plt.imshow(img)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\richie\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\RICHIE\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.distplot(df.age)
# Out:
# C:\Users\RICHIE\AppData\Local\Temp\ipykernel_17204\2409177837.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.age)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df.gender)
# Out:
# C:\Users\RICHIE\AppData\Local\Temp\ipykernel_17204\1123717698.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.gender)
# <Axes: xlabel='gender', ylabel='Density'>

# %%
files = df.iloc[0:20]
plt.figure(figsize=(15,15))
for index, file, age, gender in files.itertuples():
    plt.subplot(5,5, index+1)
    img = load_img("OneDrive/Desktop/CODECLAUSE/Gender_and_age_detection/UTKFace/"+file)
    img = np.array(img)
    plt.imshow(img)
    plt.title(f"Age: {age} Gender: {gender_dict[gender]}")
    plt.axis('off')

# %%
train, test = train_test_split(df, test_size=0.85, random_state=42)

# %%
train.head(10)
# Out:
#                                        image   age  gender
# 18199  78_1_1_20170113011857601.jpg.chip.jpg  78.0       1
# 19557  24_0_2_20170103223924087.jpg.chip.jpg  24.0       0
# 20132  34_1_3_20170119152405425.jpg.chip.jpg  34.0       1
# 11849  46_0_3_20170119183135878.jpg.chip.jpg  46.0       0
# 2100   30_0_2_20170116174814595.jpg.chip.jpg  30.0       0
# 1673   43_0_3_20170119204554406.jpg.chip.jpg  43.0       0
# 10293  24_1_0_20170117150326821.jpg.chip.jpg  24.0       1
# 4213   35_0_1_20170117192142868.jpg.chip.jpg  35.0       0
# 7480   46_0_4_20170103235306699.jpg.chip.jpg  46.0       0
# 17932  45_0_0_20170117192010084.jpg.chip.jpg  45.0       0

# %%
x_train = []
for file in train.image:
    img = load_img("OneDrive/Desktop/CODECLAUSE/Gender_and_age_detection/UTKFace/"+file, grayscale=True)
    img = img.resize((128,128), Image.ANTIALIAS)
    img = np.array(img)
    x_train.append(img)

x_train = np.array(x_train)

x_train = x_train.reshape(len(x_train), 128,128,1)
# Out:
# C:\Users\RICHIE\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
# C:\Users\RICHIE\AppData\Local\Temp\ipykernel_17204\916878612.py:4: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((128,128), Image.ANTIALIAS)

# %%
x_train.shape
# Out:
# (3556, 128, 128, 1)

# %%
x_train = x_train/255

# %%
y_gender = np.array(train.gender)
y_age = np.array(train.age)

# %%
input_size = (128,128,1)

# %%
inputs = Input((input_size))
X = Conv2D(64, (3, 3), activation='relu', kernel_initializer = glorot_uniform(seed=0))(inputs)
X = BatchNormalization(axis = 3)(X)
X = MaxPooling2D((3, 3))(X)

X = Conv2D(128, (3, 3), activation='relu')(X)
X = MaxPooling2D((2, 2), strides=(2, 2))(X)

X = Conv2D(256, (3, 3), activation='relu')(X)
X = MaxPooling2D((2, 2))(X)

X = Flatten()(X)

dense_1 = Dense(256, activation='relu')(X)
dense_2 = Dense(256, activation='relu' )(X)
dense_3 = Dense(128, activation='relu' )(dense_2)
dropout_1 = Dropout(0.4)(dense_1)
dropout_2 = Dropout(0.4)(dense_3)
output_1 = Dense(1,activation='sigmoid', name='gender_output')(dropout_1)
output_2 = Dense(1, activation='relu', name='age_output')(dropout_2)

model = Model(inputs=[inputs], outputs=[output_1,output_2])

# %%
model.compile(loss=['binary_crossentropy','mae'], optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 126, 126, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 126, 126, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 42, 42, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 40, 40, 128)  73856       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 20, 20, 128)  0          ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 18, 18, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 9, 9, 256)   0           ['conv2d_2[0][0]']
#
#  flatten (Flatten)              (None, 20736)        0           ['max_pooling2d_2[0][0]']
#
#  dense_1 (Dense)                (None, 256)          5308672     ['flatten[0][0]']
#
#  dense (Dense)                  (None, 256)          5308672     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 128)          32896       ['dense_1[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  gender_output (Dense)          (None, 1)            257         ['dropout[0][0]']
#
#  age_output (Dense)             (None, 1)            129         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 11,020,546
# Trainable params: 11,020,418
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
model_history = model.fit(x=x_train, y=[y_gender, y_age], batch_size = 10, epochs=20,validation_split= 0.1 )
# Out:
# Epoch 1/20
# 320/320 [==============================] - 99s 303ms/step - loss: 16.3596 - gender_output_loss: 0.6325 - age_output_loss: 15.7271 - gender_output_accuracy: 0.6981 - age_output_accuracy: 0.0425 - val_loss: 26.4970 - val_gender_output_loss: 0.6302 - val_age_output_loss: 25.8667 - val_gender_output_accuracy: 0.7669 - val_age_output_accuracy: 0.0337
# Epoch 2/20
# 320/320 [==============================] - 91s 283ms/step - loss: 12.9475 - gender_output_loss: 0.4642 - age_output_loss: 12.4832 - gender_output_accuracy: 0.7825 - age_output_accuracy: 0.0200 - val_loss: 13.4665 - val_gender_output_loss: 0.4556 - val_age_output_loss: 13.0110 - val_gender_output_accuracy: 0.8006 - val_age_output_accuracy: 0.0309
# Epoch 3/20
# 320/320 [==============================] - 88s 274ms/step - loss: 11.0360 - gender_output_loss: 0.4096 - age_output_loss: 10.6264 - gender_output_accuracy: 0.8100 - age_output_accuracy: 0.0125 - val_loss: 9.6448 - val_gender_output_loss: 0.4035 - val_age_output_loss: 9.2413 - val_gender_output_accuracy: 0.8034 - val_age_output_accuracy: 0.0169
# Epoch 4/20
# 320/320 [==============================] - 81s 253ms/step - loss: 9.8596 - gender_output_loss: 0.3476 - age_output_loss: 9.5120 - gender_output_accuracy: 0.8484 - age_output_accuracy: 0.0069 - val_loss: 10.2447 - val_gender_output_loss: 0.4176 - val_age_output_loss: 9.8271 - val_gender_output_accuracy: 0.8034 - val_age_output_accuracy: 0.0084
# Epoch 5/20
# 320/320 [==============================] - 80s 252ms/step - loss: 9.6352 - gender_output_loss: 0.3227 - age_output_loss: 9.3125 - gender_output_accuracy: 0.8559 - age_output_accuracy: 0.0059 - val_loss: 10.4593 - val_gender_output_loss: 0.3628 - val_age_output_loss: 10.0966 - val_gender_output_accuracy: 0.8146 - val_age_output_accuracy: 0.0197
# Epoch 6/20
# 320/320 [==============================] - 90s 283ms/step - loss: 8.9244 - gender_output_loss: 0.3011 - age_output_loss: 8.6234 - gender_output_accuracy: 0.8625 - age_output_accuracy: 0.0053 - val_loss: 8.4392 - val_gender_output_loss: 0.3545 - val_age_output_loss: 8.0847 - val_gender_output_accuracy: 0.8624 - val_age_output_accuracy: 0.0028
# Epoch 7/20
# 320/320 [==============================] - 90s 282ms/step - loss: 8.5381 - gender_output_loss: 0.2793 - age_output_loss: 8.2588 - gender_output_accuracy: 0.8784 - age_output_accuracy: 0.0059 - val_loss: 8.4717 - val_gender_output_loss: 0.3720 - val_age_output_loss: 8.0997 - val_gender_output_accuracy: 0.8371 - val_age_output_accuracy: 0.0197
# Epoch 8/20
# 320/320 [==============================] - 95s 297ms/step - loss: 8.2180 - gender_output_loss: 0.2524 - age_output_loss: 7.9656 - gender_output_accuracy: 0.8838 - age_output_accuracy: 0.0053 - val_loss: 11.8639 - val_gender_output_loss: 0.3747 - val_age_output_loss: 11.4892 - val_gender_output_accuracy: 0.8202 - val_age_output_accuracy: 0.0084
# Epoch 9/20
# 320/320 [==============================] - 82s 258ms/step - loss: 7.8135 - gender_output_loss: 0.2453 - age_output_loss: 7.5682 - gender_output_accuracy: 0.8913 - age_output_accuracy: 0.0041 - val_loss: 8.9166 - val_gender_output_loss: 0.3969 - val_age_output_loss: 8.5197 - val_gender_output_accuracy: 0.8287 - val_age_output_accuracy: 0.0140
# Epoch 10/20
# 320/320 [==============================] - 84s 262ms/step - loss: 7.5696 - gender_output_loss: 0.2104 - age_output_loss: 7.3593 - gender_output_accuracy: 0.9016 - age_output_accuracy: 0.0044 - val_loss: 13.8972 - val_gender_output_loss: 0.5035 - val_age_output_loss: 13.3937 - val_gender_output_accuracy: 0.7781 - val_age_output_accuracy: 0.0281
# Epoch 11/20
# 320/320 [==============================] - 101s 315ms/step - loss: 7.4706 - gender_output_loss: 0.1995 - age_output_loss: 7.2711 - gender_output_accuracy: 0.9122 - age_output_accuracy: 0.0044 - val_loss: 9.3460 - val_gender_output_loss: 0.3504 - val_age_output_loss: 8.9956 - val_gender_output_accuracy: 0.8680 - val_age_output_accuracy: 0.0000e+00
# Epoch 12/20
# 320/320 [==============================] - 95s 298ms/step - loss: 7.0246 - gender_output_loss: 0.1973 - age_output_loss: 6.8273 - gender_output_accuracy: 0.9072 - age_output_accuracy: 0.0034 - val_loss: 8.3398 - val_gender_output_loss: 0.3554 - val_age_output_loss: 7.9844 - val_gender_output_accuracy: 0.8736 - val_age_output_accuracy: 0.0225
# Epoch 13/20
# 320/320 [==============================] - 96s 299ms/step - loss: 6.7294 - gender_output_loss: 0.1826 - age_output_loss: 6.5468 - gender_output_accuracy: 0.9175 - age_output_accuracy: 0.0078 - val_loss: 10.8361 - val_gender_output_loss: 0.4875 - val_age_output_loss: 10.3486 - val_gender_output_accuracy: 0.8287 - val_age_output_accuracy: 0.0337
# Epoch 14/20
# 320/320 [==============================] - 95s 298ms/step - loss: 6.8915 - gender_output_loss: 0.1710 - age_output_loss: 6.7205 - gender_output_accuracy: 0.9256 - age_output_accuracy: 0.0069 - val_loss: 8.9581 - val_gender_output_loss: 0.4324 - val_age_output_loss: 8.5257 - val_gender_output_accuracy: 0.8455 - val_age_output_accuracy: 0.0084
# Epoch 15/20
# 320/320 [==============================] - 96s 299ms/step - loss: 6.4046 - gender_output_loss: 0.1538 - age_output_loss: 6.2508 - gender_output_accuracy: 0.9388 - age_output_accuracy: 0.0103 - val_loss: 9.1719 - val_gender_output_loss: 0.4491 - val_age_output_loss: 8.7229 - val_gender_output_accuracy: 0.8736 - val_age_output_accuracy: 0.0225
# Epoch 16/20
# 320/320 [==============================] - 91s 285ms/step - loss: 6.2808 - gender_output_loss: 0.1344 - age_output_loss: 6.1464 - gender_output_accuracy: 0.9381 - age_output_accuracy: 0.0106 - val_loss: 10.0251 - val_gender_output_loss: 0.4879 - val_age_output_loss: 9.5373 - val_gender_output_accuracy: 0.8511 - val_age_output_accuracy: 0.0421
# Epoch 17/20
# 320/320 [==============================] - 92s 286ms/step - loss: 6.2437 - gender_output_loss: 0.1393 - age_output_loss: 6.1044 - gender_output_accuracy: 0.9344 - age_output_accuracy: 0.0206 - val_loss: 8.4373 - val_gender_output_loss: 0.4650 - val_age_output_loss: 7.9723 - val_gender_output_accuracy: 0.8511 - val_age_output_accuracy: 0.0337
# Epoch 18/20
# 320/320 [==============================] - 92s 287ms/step - loss: 6.0458 - gender_output_loss: 0.1321 - age_output_loss: 5.9138 - gender_output_accuracy: 0.9441 - age_output_accuracy: 0.0262 - val_loss: 9.2731 - val_gender_output_loss: 0.4354 - val_age_output_loss: 8.8377 - val_gender_output_accuracy: 0.8539 - val_age_output_accuracy: 0.0421
# Epoch 19/20
# 320/320 [==============================] - 91s 285ms/step - loss: 5.8952 - gender_output_loss: 0.1349 - age_output_loss: 5.7603 - gender_output_accuracy: 0.9441 - age_output_accuracy: 0.0331 - val_loss: 8.4049 - val_gender_output_loss: 0.4834 - val_age_output_loss: 7.9215 - val_gender_output_accuracy: 0.8708 - val_age_output_accuracy: 0.0534
# Epoch 20/20
# 320/320 [==============================] - 92s 286ms/step - loss: 5.7023 - gender_output_loss: 0.1234 - age_output_loss: 5.5788 - gender_output_accuracy: 0.9469 - age_output_accuracy: 0.0331 - val_loss: 9.2384 - val_gender_output_loss: 0.5068 - val_age_output_loss: 8.7316 - val_gender_output_accuracy: 0.8287 - val_age_output_accuracy: 0.0478

# %%
plt.plot(model_history.history['gender_output_loss'])
plt.plot(model_history.history['val_gender_output_loss'])
plt.title('Gender loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(model_history.history['age_output_loss'])
plt.plot(model_history.history['val_age_output_loss'])
plt.title('Age loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import random
index= random.randint(0,3552)
print("Original: Gender = ", gender_dict[y_gender[index]]," Age = ", y_age[index])

pred = model.predict(x_train[index].reshape(1, 128, 128, 1))
pred_gender = gender_dict[round(pred[0][0][0])]
pred_age = round(pred[1][0][0])

print("Prediction: Gender = ", pred_gender," Age = ", pred_age)
plt.imshow(x_train[index].reshape(128,128), cmap='gray')
# Out:
# Original: Gender =  Female  Age =  1.0
# 1/1 [==============================] - 0s 28ms/step
# Prediction: Gender =  Female  Age =  1
